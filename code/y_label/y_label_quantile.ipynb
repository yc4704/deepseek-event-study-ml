# %%
# This cell imports the libraries used in the pipeline.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %%
print(matched.columns.tolist())
print(matched.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(matched.columns.tolist())
#       2 print(matched.head())
#
# NameError: name 'matched' is not defined
